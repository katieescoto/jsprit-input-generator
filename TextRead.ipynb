# %%
import pylab
import random
import xml.etree.ElementTree as ET
import xml.dom.minidom as MD
import numpy as np
import csv


#Attempt 5
#with open('lc101.csv', newline='') as csvfile:
    #spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    #for row in spamreader:
        #print(', '.join(row))
        
#spamreader[3:3]
shipments=[]
pickups=[]
deliveries=[]
earlytime=[]
latetime=[]
servicetime=[]


#Attempt 4
with open('lc101.csv') as f:
    #vehicles=row[0]
    reader = csv.reader(f, delimiter=';')
    next(f)
    for row in reader:
        shipments.append([row[0]])
        pickups.append([row[1]])
        deliveries.append([row[2]])
        earlytime.append([row[3]])
        latetime.append([row[4]])
        servicetime.append([row[5]])
        #pickups=pickups.append(1)
        print (row)

#print(vehicles)
#print(capacity)
print (shipments)
        


#Attempt 3
#constraints = open('lc101.csv', "rb")
#read = csv.reader(constraints)
#for row in read :
    #print (row) 

#Attempt 2
#with open ('lc101.csv', 'rb') as csvfile:
    #spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    #for row in spamreader:
         #join.row()

#Attempt 1        
#f = open('lc101.txt','r')
#line = f.read().split()
#print (line[2])
# Out:
# ['0', '40', '50', '0', '0', '1236', '0', '0', '0']
# ['1', '45', '68', '-10', '912', '967', '90', '11', '0']
# ['2', '45', '70', '-20', '825', '870', '90', '6', '0']
# ['3', '42', '66', '10', '65', '146', '90', '0', '75']
# ['4', '42', '68', '-10', '727', '782', '90', '9', '0']
# ['5', '42', '65', '10', '15', '67', '90', '0', '7']
# ['6', '40', '69', '20', '621', '702', '90', '0', '2']
# ['7', '40', '66', '-10', '170', '225', '90', '5', '0']
# ['8', '38', '68', '20', '255', '324', '90', '0', '10']
# ['9', '38', '70', '10', '534', '605', '90', '0', '4']
# ['10', '35', '66', '-20', '357', '410', '90', '8', '0']
# ['11', '35', '69', '10', '448', '505', '90', '0', '1']
# ['12', '25', '85', '-20', '652', '721', '90', '18', '0']
# ['13', '22', '75', '30', '30', '92', '90', '0', '17']
# ['14', '22', '85', '-40', '567', '620', '90', '16', '0']
# ['15', '20', '80', '-10', '384', '429', '90', '19', '0']
# ['16', '20', '85', '40', '475', '528', '90', '0', '14']
# ...
